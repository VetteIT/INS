# %% [markdown]
# # Úloha č.1
#
# ### Znenie
#
# Do nasledujúceho kódu vložte priradenia premenných tak, aby po prevedení na Pytorch tensor vzniknutý tensor mal nasledujúcu formu, vo všetkých troch prípadoch.
#
# >tensor([[2, 0, 2, 3], [2, 0, 2, 3], [2, 0, 2, 3]])
#
# ### Riešenie

# %%
array = [[2, 0, 2, 3], [2, 0, 2, 3], [2, 0, 2, 3]]
tuple = ((2, 0, 2, 3), (2, 0, 2, 3), (2, 0, 2, 3))
np_array = np.array([[2, 0, 2, 3], [2, 0, 2, 3], [2, 0, 2, 3]])

# zo zoznamu
print(torch.tensor(array))

# zo n-tice
print(torch.tensor(array))

# zo numpy array-u
print(torch.tensor(array))

# %% [markdown]
# ***
#
# # Úloha č.2
#
# ### Znenie
#
# Vyskúšajte si vytvoriť tensory s nasledujúcimi charakteristikami:
# 1. Tensor naplnený **nulami** o veľkosti  **1 * 2 * 3 * 4**
# 2. Tensor dvoch štvrocových tensorov s rozmermi **3 * 3**, naplnených **jednotkami**
# 3. Tensor naplnený **náhodnými reálnymi číslami** v tvare kocky s hranou dĺžky **5**
#
# ### Riešenie

# %%
#1
torch.zeros(1, 2, 3, 4) 

#2
torch.ones(2, 3, 3)

#3
torch.rand(5, 5, 5)

# %% [markdown]
# ***
#
# # Úloha č.3
#
# ### Znenie
#
# Máte zadaný vstupný tensor **inp**, len za pomoci vyššie spomínaných tensorových operácií vymyslite taký výpočet, ktorého výsledkom bude súčet mocnín čísla 2, od 2<sup>0</sup> po 2<sup>10</sup> (vrátane).
#
# ### Riešenie

# %%
inp = torch.tensor([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5])

# your calculation
inp = inp * 2
inp = 2 ** inp

inp
